# %% [markdown]
# # **MY FIRST ML PROJECT**

# %% [markdown]
# # **LOAD DATA**

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/refs/heads/master/delaney_solubility_with_descriptors.csv')
df
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %% [markdown]
# # **DATA PREPRATION**

# %% [markdown]
# ## DATA SEPARATION AS X & Y

# %%
y = df['logS']
y
# Out:
# 0      -2.180
# 1      -2.000
# 2      -1.740
# 3      -1.480
# 4      -3.040
#         ...
# 1139    1.144
# 1140   -4.925
# 1141   -3.893
# 1142   -3.790
# 1143   -2.581
# Name: logS, Length: 1144, dtype: float64

# %%
x = df.drop('logS' , axis=1)
x
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %% [markdown]
# ## data spliting

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2 , random_state=98)

# %%
x_train
# Out:
#      MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 931   2.1965   72.151                2.0            0.000000
# 722   6.4876  226.448               13.0            0.000000
# 486   2.2174  257.769                6.0            0.352941
# 570   3.1538  284.746                1.0            0.600000
# 296   3.2227  114.232                4.0            0.000000
# ..       ...      ...                ...                 ...
# 71    2.0253   92.569                2.0            0.000000
# 708  -3.2214  180.156                1.0            0.000000
# 65    1.7913  122.993                1.0            0.000000
# 603   0.2367   76.095                2.0            0.000000
# 554   5.9290  320.046                3.0            0.666667
#
# [915 rows x 4 columns]

# %%
x_test
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 242   1.70062  108.140                0.0            0.750000
# 769   4.61820  490.639                0.0            0.000000
# 616   3.43020  169.227                2.0            0.923077
# 422   5.64040  252.316                0.0            1.000000
# 842  -0.13030  209.253                1.0            0.400000
# ...       ...      ...                ...                 ...
# 755  -0.35930  151.129                0.0            0.818182
# 1006  5.02060  230.310                2.0            1.000000
# 260   1.41490  102.177                1.0            0.000000
# 164   2.68850  100.205                2.0            0.000000
# 910   2.51800  184.242                1.0            0.857143
#
# [229 rows x 4 columns]

# %% [markdown]
# # **MODEL BULIDING**

# %% [markdown]
# ## Linear regression

# %% [markdown]
# ### **training the model**

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### **applying the model to make pedictions**

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
y_lr_train_pred
# Out:
# array([-1.88134506e+00, -6.05452602e+00, -3.24988756e+00, -4.25329733e+00,
#        -2.91694978e+00, -8.56585567e+00, -4.81583237e+00, -2.63343834e+00,
#        -2.36187587e+00, -2.50888323e+00, -5.97030871e+00, -5.15538040e+00,
#        -1.35566580e+00, -5.16448470e+00, -2.83876744e+00,  2.00947517e+00,
#        -4.71622826e+00, -9.26983272e+00, -1.45116393e+00, -4.79539824e+00,
#        -2.35131021e+00, -3.08525389e+00, -2.79757652e+00, -1.30002731e+00,
#        -3.82757016e+00, -2.99543975e+00, -2.44905701e+00, -2.55002217e+00,
#        -3.81890842e+00, -5.38038377e+00, -3.66140033e+00, -7.86328876e+00,
#        -2.14808863e+00, -3.18229004e+00, -1.15720468e+00, -1.41619479e+00,
#        -2.73221891e+00, -2.79868813e+00, -5.38787952e+00, -1.74500984e+00,
#        -8.55684447e-01, -1.49763400e+00, -1.49154311e+00,  2.01339604e+00,
#        -3.48878905e+00, -4.82696016e+00, -2.33671890e+00, -4.31159179e+00,
# ...

# %% [markdown]
# ### evaluate model performance

# %%
from sklearn.metrics import mean_squared_error , r2_score
lr_train_mse = mean_squared_error(y_train , y_lr_train_pred)
lr_train_r2 = r2_score(y_train , y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test , y_lr_test_pred)
lr_test_r2 = r2_score(y_test , y_lr_test_pred)

# %%
print('LR MSE (Train): ' , lr_train_mse)
print('LR R2 (Train): ' , lr_train_r2)
print('LR MSE (Test): ' , lr_test_mse)
print('LR R2 (Test): ' , lr_test_r2)
# Out:
# LR MSE (Train):  1.0298822509778036
# LR R2 (Train):  0.7630861560269245
# LR MSE (Test):  0.9359825112088095
# LR R2 (Test):  0.7950944627380776

# %%
lr_results = pd.DataFrame(['linear regression' , lr_train_mse , lr_train_r2 , lr_test_mse , lr_test_r2]).transpose()
lr_results.columns = ['algorithm' , 'trainingc mse' , 'training r2' , 'testing mse' , 'testing r2']

# %%
lr_results
# Out:
#            algorithm trainingc mse training r2 testing mse testing r2
# 0  linear regression      1.029882    0.763086    0.935983   0.795094

# %% [markdown]
# ## **RANDOM FOREST**

# %% [markdown]
# ### TRAINING THE MODEL

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=2 , random_state=98)
rf.fit(x_train , y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=98)

# %% [markdown]
# ### APPLYING THE MODEL TO MAKE PREDICTION

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)

# %% [markdown]
# ### EVALUATING THE MODEL PERFORMANCE

# %%
from sklearn.metrics import mean_squared_error , r2_score
rf_train_mse = mean_squared_error(y_train , y_rf_train_pred)
rf_train_r2 = r2_score(y_train , y_rf_train_pred)
rf_test_mse = mean_squared_error(y_test , y_rf_test_pred)
rf_test_r2 = r2_score(y_test , y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random Forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['algorithm', 'trainingc mse', 'training r2', 'testing mse', 'Training MSE']
rf_results
# Out:
#        algorithm trainingc mse training r2 testing mse Training MSE
# 0  Random Forest      1.055164     0.75727    1.266866     0.722657

# %% [markdown]
# # **MODEL COMAPRISON**

# %%
df_models = pd.concat([lr_results, rf_results], axis=0)
df_models
# Out:
#            algorithm trainingc mse training r2 testing mse testing r2 Training MSE
# 0  linear regression      1.029882    0.763086    0.935983   0.795094          NaN
# 0      Random Forest      1.055164     0.75727    1.266866        NaN     0.722657

# %%
df_models.reset_index(drop=True)
# Out:
#            algorithm trainingc mse training r2 testing mse testing r2 Training MSE
# 0  linear regression      1.029882    0.763086    0.935983   0.795094          NaN
# 1      Random Forest      1.055164     0.75727    1.266866        NaN     0.722657

# %% [markdown]
# # **DATA VISUALIZATION OF PREDICION RESULTS**

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(5,5))
plt.scatter(x=y_train , y=y_lr_train_pred , c='g' , alpha=0.3)
z = np.polyfit(y_train , y_lr_train_pred , 1)
p = np.poly1d(z)
plt.plot(y_train , p(y_train) , c='r')
plt.ylabel('predicted logS')
plt.xlabel('Experimental logS')
# Out:
# Text(0.5, 0, 'Experimental logS')
